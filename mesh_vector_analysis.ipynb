# %% [markdown]
# <h2>3D Mesh Vector Analysis</h2>
#
# <h3><b>1. Mesh Generation</b></h3>
#
# Parameter Selection:
#
#
#    <b>Input Path</b>:<br>
#    Path to the model_prediction or segmemntation files.<br>
#
#    <b>Smooth Mesh</b>:<br>
#    Apply Smooth to the generated meshes.<br>
#
#    This part will generate the .stl files containing the mesh associated to the segmentation one with the string vessel information and other with the normal vessel information.

# %%
from core.mesh import mesh_menu
mesh_menu()

# %% [markdown]
# <h3><b>2. Vector Computation</b></h3>
#
# Generarte Vector Map:
#
#    <b>Input Path</b>:<br>
#    Path to the mesh_vect_out folder.<br>
#
# <b>Used mesh</b>:<br>
#    Select the kind of mesh used for the vector computation.<br>
#    <span style="color:red;"><b>Note:</b></span>
#     Smooth only can be used if the smooth mesh was generated in the previous step. In the other case the Normal mesh will be used.<br><br>
#
# This part will generate:
# The 3D vector map in a .npy file for the normal and tangent vectors of the segmentation:
# CSV files with the information of the mean and standar deviation computation for each conected componet in the segmentation (local directional infromation for the surface)

# %%
from core.mesh import vector_menu
vector_menu()

# %% [markdown]
# <h3><b>3. Vector Visualization (optional)</b></h3>
#
# Visualize Vector Map:
#
# This part helps to deploy in an automatically way the vector map using Napari, to visualize the generated mesh, the segmentation and the original image juts drop the corresponding files into the interface of Napari as usual.
#
#    <b>Input Path</b>:<br>
#    Path to the folder of vectors (.npy) to visualize.<br>
#
# <span style="color:red;"><b>Note:</b></span>
# This step require the use of the graphical interface Napari to show the results, if you are working in a cluster or other resource without graphical interface this part won't work.<br>
# To run this part in a graphical mode please follow the instruction in the repository.<br>
# (If you only drag the .npy files into Napari these files are not displayed correctly because Napari interpret them as images and not as vectors.)<br>

# %%
from core.mesh import visualizer_menu
visualizer_menu()
